# %%
import torch
from fastai.vision.all import *
from fastai.learner import load_learner
from fastai.data.core import DataLoaders

# %%
path_to_data = '/workspace/data/TRAINING_DATA'
path_to_pth_model = '/workspace/models/model_epoch8' # leave off the .pth here
path_to_models = '/workspace/models/'
dls = ImageDataLoaders.from_folder(path_to_data, train='.', valid_pct=0.2) # be sure to use the same validation split that you did for previous training

learn = vision_learner(dls, resnet18) # be sure to use the same pretrained model here that you did for previous training
learn.load(path_to_pth_model)  # Load the model from the .pth file
learn.export(path_to_models+'model_epoch8.pkl')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 7
#       4 dls = ImageDataLoaders.from_folder(path_to_data, train='.', valid_pct=0.2) # be sure to use the same validation split that you did for previous training
#       6 learn = vision_learner(dls, resnet18) # be sure to use the same pretrained model here that you did for previous training
# ----> 7 learn.load(path_to_pth_model)  # Load the model from the .pth file
#       8 learn.export(path_to_models+'model_epoch8.pkl')
#
# File /usr/local/lib/python3.8/dist-packages/fastai/learner.py:420, in load(self, file, device, **kwargs)
#     418 file = join_path_file(file, self.path/self.model_dir, ext='.pth')
#     419 distrib_barrier()
# --> 420 load_model(file, self.model, self.opt, device=device, **kwargs)
#     421 return self
#
# File /usr/local/lib/python3.8/dist-packages/fastai/learner.py:54, in load_model(file, model, opt, with_opt, device, strict, **torch_load_kwargs)
#      52 hasopt = set(state)=={'model', 'opt'}
#      53 model_state = state['model'] if hasopt else state
# ---> 54 get_model(model).load_state_dict(model_state, strict=strict)
#      55 if hasopt and with_opt:
#      56     try: opt.load_state_dict(state['opt'])
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:2189, in Module.load_state_dict(self, state_dict, strict, assign)
#    2184         error_msgs.insert(
#    2185             0, 'Missing key(s) in state_dict: {}. '.format(
#    2186                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2188 if len(error_msgs) > 0:
# -> 2189     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2190                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2191 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Sequential:
# 	Missing key(s) in state_dict: "0.0.weight", "0.1.weight", "0.1.bias", "0.1.running_mean", "0.1.running_var", "0.4.0.conv1.weight", "0.4.0.bn1.weight", "0.4.0.bn1.bias", "0.4.0.bn1.running_mean", "0.4.0.bn1.running_var", "0.4.0.conv2.weight", "0.4.0.bn2.weight", "0.4.0.bn2.bias", "0.4.0.bn2.running_mean", "0.4.0.bn2.running_var", "0.4.1.conv1.weight", "0.4.1.bn1.weight", "0.4.1.bn1.bias", "0.4.1.bn1.running_mean", "0.4.1.bn1.running_var", "0.4.1.conv2.weight", "0.4.1.bn2.weight", "0.4.1.bn2.bias", "0.4.1.bn2.running_mean", "0.4.1.bn2.running_var", "0.5.0.conv1.weight", "0.5.0.bn1.weight", "0.5.0.bn1.bias", "0.5.0.bn1.running_mean", "0.5.0.bn1.running_var", "0.5.0.conv2.weight", "0.5.0.bn2.weight", "0.5.0.bn2.bias", "0.5.0.bn2.running_mean", "0.5.0.bn2.running_var", "0.5.0.downsample.0.weight", "0.5.0.downsample.1.weight", "0.5.0.downsample.1.bias", "0.5.0.downsample.1.running_mean", "0.5.0.downsample.1.running_var", "0.5.1.conv1.weight", "0.5.1.bn1.weight", "0.5.1.bn1.bias", "0.5.1.bn1.running_mean", "0.5.1.bn1.running_var", "0.5.1.conv2.weight", "0.5.1.bn2.weight", "0.5.1.bn2.bias", "0.5.1.bn2.running_mean", "0.5.1.bn2.running_var", "0.6.0.conv1.weight", "0.6.0.bn1.weight", "0.6.0.bn1.bias", "0.6.0.bn1.running_mean", "0.6.0.bn1.running_var", "0.6.0.conv2.weight", "0.6.0.bn2.weight", "0.6.0.bn2.bias", "0.6.0.bn2.
attn.proj.ln.bn.num_batches_tracked", "0.model.stages.0.blocks.0.mlp.ln1.linear.weight", "0.model.stages.0.blocks.0.mlp.ln1.bn.weight", "0.model.stages.0.blocks.0.mlp.ln1.bn.bias", "0.model.stages.0.blocks.0.mlp.ln1.bn.running_mean", "0.model.stages.0.blocks.0.mlp.ln1.bn.running_var", "0.model.stages.0.blocks.0.mlp.ln1.bn.num_batches_tracked", "0.model.stages.0.blocks.0.mlp.ln2.linear.weight", "0.model.stages.0.blocks.0.mlp.ln2.bn.weight", "0.model.stages.0.blocks.0.mlp.ln2.bn.bias", "0.model.stages.0.blocks.0.mlp.ln2.bn.running_mean", "0.model.stages.0.blocks.0.mlp.ln2.bn.running_var", "0.model.stages.0.blocks.0.mlp.ln2.bn.num_batches_tracked", "0.model.stages.0.blocks.1.attn.attention_biases", "0.model.stages.0.blocks.1.attn.qkv.linear.weight", "0.model.stages.0.blocks.1.attn.qkv.bn.weight", "0.model.stages.0.blocks.1.attn.qkv.bn.bias", "0.model.stages.0.blocks.1.attn.qkv.bn.running_mean", "0.model.stages.0.blocks.1.attn.qkv.bn.running_var", "0.model.stages.0.blocks.1.attn.qkv.bn.num_batches_tracked", "0.model.stages.0.blocks.1.attn.proj.ln.linear.weight", "0.model.stages.0.blocks.1.attn.proj.ln.bn.weight", "0.model.stages.0.blocks.1.attn.proj.ln.bn.bias", "0.model.stages.0.blocks.1.attn.proj.ln.bn.running_mean", "0.model.stages.0.blocks.1.attn.proj.ln.bn.running_var", "0.model.stages.0.blocks.1.attn.proj.ln.bn.num_batches_tracked", "0.model.stages.0.blocks.1.mlp.ln1.linear.weight", "0.model.stages.0.blocks.1.mlp.ln1.bn.weight", "0.model.stages.0.blocks.1.mlp.ln1.bn.bias", "0.model.stages.0.blocks.1.mlp.ln1.bn.running_mean", "0.model.stages.0.blocks.1.mlp.ln1.bn.running_var", "0.model.stages.0.blocks.1.mlp.ln1.bn.num_batches_tracked", "0.model.stages.0.blocks.1.mlp.ln2.linear.weight", "0.model.stages.0.blocks.1.mlp.ln2.bn.weight", "0.model.stages.0.blocks.1.mlp.ln2.bn.bias", "0.model.stages.0.blocks.1.mlp.ln2.bn.running_mean", "0.model.stages.0.blocks.1.mlp.ln2.bn.running_var", "0.model.stages.0.blocks.1.mlp.ln2.bn.num_batches_tracked", "0.model.stages.0.blocks.2.attn.attention_biases", "0.model.stages.0.blocks.2.attn.qkv.linear.weight", "0.model.stages.0.blocks.2.attn.qkv.bn.weight", "0.model.stages.0.blocks.2.attn.qkv.bn.bias", "0.model.stages.0.blocks.2.attn.qkv.bn.running_mean", "0.model.stages.0.blocks.2.attn.qkv.bn.running_var", "0.model.stages.0.blocks.2.attn.qkv.bn.num_batches_tracked", "0.model.stages.0.blocks.2.attn.proj.ln.linear.weight", "0.model.stages.0.blocks.2.attn.pro ...
# 	size mismatch for 1.2.weight: copying a param with shape torch.Size([512, 768]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for 1.4.weight: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([512, 1024]).
# 	size mismatch for 1.6.weight: copying a param with shape torch.Size([9, 512]) from checkpoint, the shape in current model is torch.Size([512]).
